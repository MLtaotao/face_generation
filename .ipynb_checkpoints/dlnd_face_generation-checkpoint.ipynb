# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Downloading celeba: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-2fe1a6e71a9d> in <module>()
#      11
#      12 helper.download_extract('mnist', data_dir)
# ---> 13 helper.download_extract('celeba', data_dir)
#
# c:\python\DLND\face_generation\helper.py in download_extract(database_name, data_path)
#     158                 url,
#     159                 save_path,
# --> 160                 pbar.hook)
#     161
#     162     assert hashlib.md5(open(save_path, 'rb').read()).hexdigest() == hash_code, \
#
# C:\Users\xuans\Anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     186     url_type, path = splittype(url)
#     187
# --> 188     with contextlib.closing(urlopen(url, data)) as fp:
#     189         headers = fp.info()
#     190
#
# C:\Users\xuans\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# C:\Users\xuans\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
#     468         # post-process response
#
# C:\Users\xuans\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     482         protocol = req.type
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#     486             return result
#
# C:\Users\xuans\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# C:\Users\xuans\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1295         def https_open(self, req):
#    1296             return self.do_open(http.client.HTTPSConnection, req,
# -> 1297                 context=self._context, check_hostname=self._check_hostname)
#    1298
#    1299         https_request = AbstractHTTPHandler.do_request_
#
# C:\Users\xuans\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1255             except OSError as err: # timeout error
#    1256                 raise URLError(err)
# -> 1257             r = h.getresponse()
#    1258         except:
#    1259             h.close()
#
# C:\Users\xuans\Anaconda3\lib\http\client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# C:\Users\xuans\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\Users\xuans\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\Users\xuans\Anaconda3\lib\socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# C:\Users\xuans\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#     927                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     928                   self.__class__)
# --> 929             return self.read(nbytes, buffer)
#     930         else:
#     931             return socket.recv_into(self, buffer, nbytes, flags)
#
# C:\Users\xuans\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     789             raise ValueError("Read on closed or unwrapped SSL socket.")
#     790         try:
# --> 791             return self._sslobj.read(len, buffer)
#     792         except SSLError as x:
#     793             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# C:\Users\xuans\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     573         """
#     574         if buffer is not None:
# --> 575             v = self._sslobj.read(len, buffer)
#     576         else:
#     577             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
import pickle as pkl

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# C:\Users\xuans\Anaconda3\lib\site-packages\ipykernel\__main__.py:15: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    #creat real input images placeholder
    inputs_images = tf.placeholder(tf.float32, (None, image_width ,image_height , image_channels), name= 'inputs_images')
    #creat input z placeholder
    inputs_z = tf.placeholder(tf.float32, (None, z_dim), name= 'inputs_z')
    #creat learning_rate placeholder
    learn_rate = tf.placeholder(tf.float32)

    return inputs_images, inputs_z, learn_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param image: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    with tf.variable_scope('discriminator', reuse= reuse):
        #input layer is 28*28*3
        x1 = tf.layers.conv2d(images, 64, 5, strides= 2, padding= 'same')
        relu1 = tf.maximum(0.01 * x1, x1)
        #14*14*64 now
        
        x2 = tf.layers.conv2d(relu1, 128, 5, strides= 2, padding= 'same')
        bn2 = tf.layers.batch_normalization(x2, training= True)
        relu2 = tf.maximum(0.01* bn2, bn2)
        #7*7*128 now
        
        x3 = tf.layers.conv2d(relu2, 256, 5, strides= 2, padding= 'same')
        bn3 = tf.layers.batch_normalization(x3, training= True)
        relu3 = tf.maximum(0.01 * bn3, bn3)
        #4 *4 *256 now
        
        flat = tf.reshape(relu3, (-1, 4*4*256))
        drop = tf.nn.dropout(flat, keep_prob= 0.8)
        logits = tf.layers.dense(drop, 1)
        out = tf.sigmoid(logits)
        

    return out, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    with tf.variable_scope('generator', reuse= not is_train):
        #first fully connected layer
        x1 = tf.layers.dense(z, 4*4*512)
        if is_train:
            x1 = tf.nn.dropout(x1, keep_prob= 0.8)
        #reshape layer and start cnn
        x1 = tf.reshape(x1, (-1, 4, 4, 512))
        x1 = tf.layers.batch_normalization(x1, training= is_train)
        x1 = tf.maximum(0.01* x1, x1)
        #4*4*512now
        
        x2 = tf.layers.conv2d_transpose(x1, 256, 5, strides= 2, padding= 'same')
        x2 = tf.layers.batch_normalization(x2, training= is_train)
        x2 = tf.maximum(0.01 * x2, x2)
        #8*8*256
        
        x3 = tf.layers.conv2d_transpose(x2, 128, 5, strides= 2, padding= 'same')
        x3 = tf.layers.batch_normalization(x3, training= is_train)
        x3 = tf.maximum(0.01 *x3, x3)
        #16*16*128
        
        x4 = tf.layers.conv2d_transpose(x3, out_channel_dim, 5, strides= 2, padding= 'same')
        #32*32*?
        
        logits = tf.image.resize_images(x4, (28,28))
        out = tf.tanh(logits)
    
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    g_model = generator(input_z, out_channel_dim)
    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse= True)
    
    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits= d_logits_real, labels= tf.ones_like(d_model_real) + 0.1))
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits= d_logits_fake, labels= tf.zeros_like(d_model_fake)))
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits= d_logits_fake, labels= tf.ones_like(d_model_fake)))
    
    d_loss = d_loss_real + d_loss_fake
    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    #get weights and bias to update
    t_vars = tf.trainable_variables()
    
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]
    
    #apply optimize
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1).minimize(d_loss, var_list = d_vars)
        g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1).minimize(g_loss, var_list = g_vars)
    
    return d_train_opt, g_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    #tf.reset_default_graph()
    
    n_samples, width, height, channels = data_shape
    input_real, input_z, learn_rate = model_inputs(width, height, channels, z_dim)
    d_loss, g_loss = model_loss(input_real, input_z, channels)
    d_opt, g_opt = model_opt(d_loss, g_loss, learn_rate, beta1)

    print_every=10
    show_every=100
    
    saver = tf.train.Saver()

    samples, losses = [], []
    steps = 0
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                batch_images *= 2
                steps += 1
                
                #sample random noise for G
                batch_z = np.random.uniform(-1, 1, size= (batch_size, z_dim))
                
                #run optimizer
                _ = sess.run(d_opt, feed_dict = {input_real : batch_images, input_z : batch_z, learn_rate: learning_rate})
                _ = sess.run(g_opt, feed_dict = {input_real : batch_images, input_z : batch_z, learn_rate: learning_rate})
                _ = sess.run(g_opt, feed_dict = {input_real : batch_images, input_z : batch_z, learn_rate: learning_rate})
                _ = sess.run(g_opt, feed_dict = {input_real : batch_images, input_z : batch_z, learn_rate: learning_rate})
                
                if steps % print_every == 0:
                    # At the end of each epoch, get the losses and print them out
                    train_loss_d = d_loss.eval({input_z: batch_z, input_real: batch_images})
                    train_loss_g = g_loss.eval({input_z: batch_z})
                    
                    print("Epoch {}/{}...".format(epoch_i, epochs),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                    # Save losses to view after training
                    losses.append((train_loss_d, train_loss_g))
                    
                if steps % show_every == 0:
                    show_generator_output(sess, 36, input_z, channels, data_image_mode)
                    
        saver.save(sess, './checkpoints/generator.ckpt')
        
    with open('samples.pkl', 'wb') as f:
        pkl.dump(samples, f)

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.0009
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    #tf.reset_default_graph()
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 0/2... Discriminator Loss: 0.1661... Generator Loss: 20.0592
# Epoch 0/2... Discriminator Loss: 5.6114... Generator Loss: 0.0041
# Epoch 0/2... Discriminator Loss: 0.1379... Generator Loss: 19.7321
# Epoch 0/2... Discriminator Loss: 0.4128... Generator Loss: 3.4743
# Epoch 0/2... Discriminator Loss: 3.8588... Generator Loss: 8.9604
# Epoch 0/2... Discriminator Loss: 5.0882... Generator Loss: 0.0160
# Epoch 0/2... Discriminator Loss: 0.5018... Generator Loss: 2.6577
# Epoch 0/2... Discriminator Loss: 1.0417... Generator Loss: 3.0170
# Epoch 0/2... Discriminator Loss: 0.7885... Generator Loss: 1.0166
# Epoch 0/2... Discriminator Loss: 1.1250... Generator Loss: 2.5131
# Epoch 0/2... Discriminator Loss: 0.6747... Generator Loss: 1.2573
# Epoch 0/2... Discriminator Loss: 0.5947... Generator Loss: 1.9307
# Epoch 0/2... Discriminator Loss: 0.9686... Generator Loss: 1.2277
# Epoch 0/2... Discriminator Loss: 1.5970... Generator Loss: 2.6723
# Epoch 0/2... Discriminator Loss: 1.0289... Generator Loss: 1.7075
# Epoch 0/2... Discriminator Loss: 0.6216... Generator Loss: 2.4167
# Epoch 0/2... Discriminator Loss: 1.4623... Generator Loss: 0.4619
# Epoch 0/2... Discriminator Loss: 0.7536... Generator Loss: 1.3935
# Epoch 0/2... Discriminator Loss: 1.0226... Generator Loss: 1.8929
# Epoch 0/2... Discriminator Loss: 1.0318... Generator Loss: 1.3070
# Epoch 0/2... Discriminator Loss: 0.7007... Generator Loss: 1.2728
# Epoch 0/2... Discriminator Loss: 0.9984... Generator Loss: 0.8777
# Epoch 0/2... Discriminator Loss: 0.5830... Generator Loss: 1.5114
# Epoch 0/2... Discriminator Loss: 0.8300... Generator Loss: 1.1089
# Epoch 0/2... Discriminator Loss: 0.5768... Generator Loss: 2.4454
# Epoch 0/2... Discriminator Loss: 0.6040... Generator Loss: 1.8154
# Epoch 0/2... Discriminator Loss: 1.3070... Generator Loss: 0.5141
# Epoch 0/2... Discriminator Loss: 0.6531... Generator Loss: 2.4181
# Epoch 0/2... Discriminator Loss: 0.7633... Generator Loss: 2.3107
# Epoch 0/2... Discriminator Loss: 0.8498... Generator Loss: 0.9671
# Epoch 0/2... Discriminator Loss: 0.6994... Generator Loss: 1.5547
# Epoch 0/2... Discriminator Loss: 0.8618... Generator Loss: 1.1897
# Epoch 0/2... Discriminator Loss: 0.8104... Generator Loss: 1.3141
# Epoch 0/2... Discriminator Loss: 1.3859... Generator Loss: 0.5187
# Epoch 0/2... Discriminator Loss: 0.7262... Generator Loss: 1.2107
# Epoch 0/2... Discriminator Loss: 0.9204... Generator Loss: 0.9949
# Epoch 0/2... Discriminator Loss: 0.7177... Generator Loss: 1.4436
# Epoch 0/2... Discriminator Loss: 1.6524... Generator Loss: 0.3413
# Epoch 0/2... Discriminator Loss: 0.7758... Generator Loss: 1.4135
# Epoch 0/2... Discriminator Loss: 1.1152... Generator Loss: 0.7126
# Epoch 0/2... Discriminator Loss: 1.1145... Generator Loss: 2.0063
# Epoch 0/2... Discriminator Loss: 0.9232... Generator Loss: 0.9641
# Epoch 0/2... Discriminator Loss: 0.8915... Generator Loss: 1.2089
# Epoch 0/2... Discriminator Loss: 0.8248... Generator Loss: 1.8459
# Epoch 0/2... Discriminator Loss: 1.1051... Generator Loss: 0.6372
# Epoch 0/2... Discriminator Loss: 0.7428... Generator Loss: 1.5695
# Epoch 1/2... Discriminator Loss: 0.9738... Generator Loss: 1.9406
# Epoch 1/2... Discriminator Loss: 0.7657... Generator Loss: 1.5949
# Epoch 1/2... Discriminator Loss: 1.1643... Generator Loss: 0.6516
# Epoch 1/2... Discriminator Loss: 0.9592... Generator Loss: 1.7967
# Epoch 1/2... Discriminator Loss: 0.9927... Generator Loss: 0.7307
# Epoch 1/2... Discriminator Loss: 1.3056... Generator Loss: 0.5736
# Epoch 1/2... Discriminator Loss: 0.8724... Generator Loss: 1.1235
# Epoch 1/2... Discriminator Loss: 0.8029... Generator Loss: 0.9723
# Epoch 1/2... Discriminator Loss: 1.2356... Generator Loss: 0.5621
# Epoch 1/2... Discriminator Loss: 1.4073... Generator Loss: 2.2731
# Epoch 1/2... Discriminator Loss: 0.8572... Generator Loss: 0.9201
# Epoch 1/2... Discriminator Loss: 0.8945... Generator Loss: 0.9965
# Epoch 1/2... Discriminator Loss: 0.7829... Generator Loss: 0.9054
# Epoch 1/2... Discriminator Loss: 1.0799... Generator Loss: 1.5085
# Epoch 1/2... Discriminator Loss: 0.6683... Generator Loss: 1.4560
# Epoch 1/2... Discriminator Loss: 1.1649... Generator Loss: 2.1727
# Epoch 1/2... Discriminator Loss: 1.1244... Generator Loss: 0.6005
# Epoch 1/2... Discriminator Loss: 0.9080... Generator Loss: 0.8008
# Epoch 1/2... Discriminator Loss: 0.7350... Generator Loss: 1.4759
# Epoch 1/2... Discriminator Loss: 1.2400... Generator Loss: 0.5156
# Epoch 1/2... Discriminator Loss: 0.9377... Generator Loss: 1.7410
# Epoch 1/2... Discriminator Loss: 1.5532... Generator Loss: 0.3682
# Epoch 1/2... Discriminator Loss: 1.5194... Generator Loss: 0.3438
# Epoch 1/2... Discriminator Loss: 0.9167... Generator Loss: 0.9029
# Epoch 1/2... Discriminator Loss: 0.9673... Generator Loss: 0.8777
# Epoch 1/2... Discriminator Loss: 1.0490... Generator Loss: 0.7069
# Epoch 1/2... Discriminator Loss: 1.4613... Generator Loss: 2.5938
# Epoch 1/2... Discriminator Loss: 0.8285... Generator Loss: 1.2696
# Epoch 1/2... Discriminator Loss: 1.2179... Generator Loss: 0.4770
# Epoch 1/2... Discriminator Loss: 0.9304... Generator Loss: 1.7740
# Epoch 1/2... Discriminator Loss: 1.6611... Generator Loss: 1.8418
# Epoch 1/2... Discriminator Loss: 0.9391... Generator Loss: 1.2506
# Epoch 1/2... Discriminator Loss: 1.4027... Generator Loss: 2.4563
# Epoch 1/2... Discriminator Loss: 0.8823... Generator Loss: 1.1110
# Epoch 1/2... Discriminator Loss: 0.8697... Generator Loss: 1.4697
# Epoch 1/2... Discriminator Loss: 1.1687... Generator Loss: 2.0758
# Epoch 1/2... Discriminator Loss: 0.9884... Generator Loss: 0.7487
# Epoch 1/2... Discriminator Loss: 0.7615... Generator Loss: 2.0402
# Epoch 1/2... Discriminator Loss: 0.8642... Generator Loss: 2.1089
# Epoch 1/2... Discriminator Loss: 0.8085... Generator Loss: 0.9864
# Epoch 1/2... Discriminator Loss: 0.8475... Generator Loss: 0.8940
# Epoch 1/2... Discriminator Loss: 1.2770... Generator Loss: 0.7366
# Epoch 1/2... Discriminator Loss: 1.0256... Generator Loss: 0.9566
# Epoch 1/2... Discriminator Loss: 1.0632... Generator Loss: 0.6203
# Epoch 1/2... Discriminator Loss: 0.7910... Generator Loss: 1.1934
# Epoch 1/2... Discriminator Loss: 1.1787... Generator Loss: 0.5849
# Epoch 1/2... Discriminator Loss: 1.0706... Generator Loss: 0.8883

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.0009
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 0/1... Discriminator Loss: 0.0183... Generator Loss: 7.5783
# Epoch 0/1... Discriminator Loss: 0.1315... Generator Loss: 14.2821
# Epoch 0/1... Discriminator Loss: 0.2474... Generator Loss: 2.0501
# Epoch 0/1... Discriminator Loss: 0.0700... Generator Loss: 3.7422
# Epoch 0/1... Discriminator Loss: 0.3487... Generator Loss: 4.4821
# Epoch 0/1... Discriminator Loss: 1.4922... Generator Loss: 0.4923
# Epoch 0/1... Discriminator Loss: 2.9892... Generator Loss: 5.1094
# Epoch 0/1... Discriminator Loss: 2.1495... Generator Loss: 0.4708
# Epoch 0/1... Discriminator Loss: 0.9340... Generator Loss: 0.9912
# Epoch 0/1... Discriminator Loss: 0.6784... Generator Loss: 1.1915
# Epoch 0/1... Discriminator Loss: 0.9571... Generator Loss: 0.8529
# Epoch 0/1... Discriminator Loss: 2.0129... Generator Loss: 0.5223
# Epoch 0/1... Discriminator Loss: 1.0752... Generator Loss: 0.6839
# Epoch 0/1... Discriminator Loss: 2.6318... Generator Loss: 5.3615
# Epoch 0/1... Discriminator Loss: 0.7269... Generator Loss: 1.0695
# Epoch 0/1... Discriminator Loss: 2.3473... Generator Loss: 0.1697
# Epoch 0/1... Discriminator Loss: 0.6172... Generator Loss: 2.1703
# Epoch 0/1... Discriminator Loss: 0.7605... Generator Loss: 1.2863
# Epoch 0/1... Discriminator Loss: 0.9915... Generator Loss: 0.8312
# Epoch 0/1... Discriminator Loss: 0.7157... Generator Loss: 2.8837
# Epoch 0/1... Discriminator Loss: 0.4826... Generator Loss: 1.9974
# Epoch 0/1... Discriminator Loss: 1.6987... Generator Loss: 3.2963
# Epoch 0/1... Discriminator Loss: 1.7015... Generator Loss: 3.0490
# Epoch 0/1... Discriminator Loss: 0.9965... Generator Loss: 2.7879
# Epoch 0/1... Discriminator Loss: 0.8009... Generator Loss: 1.5140
# Epoch 0/1... Discriminator Loss: 0.8924... Generator Loss: 0.6711
# Epoch 0/1... Discriminator Loss: 0.5470... Generator Loss: 1.6261
# Epoch 0/1... Discriminator Loss: 0.7162... Generator Loss: 1.2071
# Epoch 0/1... Discriminator Loss: 1.0740... Generator Loss: 0.6501
# Epoch 0/1... Discriminator Loss: 1.0031... Generator Loss: 1.0399
# Epoch 0/1... Discriminator Loss: 0.5893... Generator Loss: 2.0603
# Epoch 0/1... Discriminator Loss: 1.2712... Generator Loss: 0.4667
# Epoch 0/1... Discriminator Loss: 1.0067... Generator Loss: 0.9323
# Epoch 0/1... Discriminator Loss: 0.8424... Generator Loss: 0.8271
# Epoch 0/1... Discriminator Loss: 1.1069... Generator Loss: 2.0916
# Epoch 0/1... Discriminator Loss: 1.0852... Generator Loss: 2.8735
# Epoch 0/1... Discriminator Loss: 1.0861... Generator Loss: 2.8922
# Epoch 0/1... Discriminator Loss: 0.6422... Generator Loss: 1.2984
# Epoch 0/1... Discriminator Loss: 0.9615... Generator Loss: 3.4354
# Epoch 0/1... Discriminator Loss: 1.0777... Generator Loss: 0.7475
# Epoch 0/1... Discriminator Loss: 0.7730... Generator Loss: 1.8097
# Epoch 0/1... Discriminator Loss: 0.8049... Generator Loss: 1.4193
# Epoch 0/1... Discriminator Loss: 1.2080... Generator Loss: 0.4822
# Epoch 0/1... Discriminator Loss: 1.9452... Generator Loss: 3.9960
# Epoch 0/1... Discriminator Loss: 1.6728... Generator Loss: 0.3061
# Epoch 0/1... Discriminator Loss: 1.5842... Generator Loss: 2.9267
# Epoch 0/1... Discriminator Loss: 0.8794... Generator Loss: 0.8656
# Epoch 0/1... Discriminator Loss: 0.6843... Generator Loss: 1.8624
# Epoch 0/1... Discriminator Loss: 1.1737... Generator Loss: 0.5327
# Epoch 0/1... Discriminator Loss: 1.2081... Generator Loss: 3.2278
# Epoch 0/1... Discriminator Loss: 0.7813... Generator Loss: 1.2693
# Epoch 0/1... Discriminator Loss: 0.8344... Generator Loss: 3.9249
# Epoch 0/1... Discriminator Loss: 0.7550... Generator Loss: 1.7577
# Epoch 0/1... Discriminator Loss: 1.0858... Generator Loss: 0.6641
# Epoch 0/1... Discriminator Loss: 0.7304... Generator Loss: 1.2266
# Epoch 0/1... Discriminator Loss: 0.6697... Generator Loss: 1.9322
# Epoch 0/1... Discriminator Loss: 0.6943... Generator Loss: 1.1141
# Epoch 0/1... Discriminator Loss: 0.5617... Generator Loss: 2.9703
# Epoch 0/1... Discriminator Loss: 1.2268... Generator Loss: 0.6134
# Epoch 0/1... Discriminator Loss: 0.7302... Generator Loss: 2.5919
# Epoch 0/1... Discriminator Loss: 0.7832... Generator Loss: 0.9456
# Epoch 0/1... Discriminator Loss: 1.1422... Generator Loss: 0.6994
# Epoch 0/1... Discriminator Loss: 0.9433... Generator Loss: 0.9087
# Epoch 0/1... Discriminator Loss: 1.7585... Generator Loss: 0.3016
# Epoch 0/1... Discriminator Loss: 0.9472... Generator Loss: 1.1453
# Epoch 0/1... Discriminator Loss: 1.9694... Generator Loss: 3.4206
# Epoch 0/1... Discriminator Loss: 1.7281... Generator Loss: 0.3281
# Epoch 0/1... Discriminator Loss: 1.1098... Generator Loss: 0.6821
# Epoch 0/1... Discriminator Loss: 0.8247... Generator Loss: 1.0775
# Epoch 0/1... Discriminator Loss: 0.9425... Generator Loss: 1.0489
# Epoch 0/1... Discriminator Loss: 0.7776... Generator Loss: 1.3946
# Epoch 0/1... Discriminator Loss: 1.2750... Generator Loss: 1.2891
# Epoch 0/1... Discriminator Loss: 1.0109... Generator Loss: 1.2407
# Epoch 0/1... Discriminator Loss: 0.9047... Generator Loss: 2.3244
# Epoch 0/1... Discriminator Loss: 1.0299... Generator Loss: 1.4163
# Epoch 0/1... Discriminator Loss: 1.6927... Generator Loss: 3.1728
# Epoch 0/1... Discriminator Loss: 1.4908... Generator Loss: 0.3846
# Epoch 0/1... Discriminator Loss: 1.3952... Generator Loss: 0.4490
# Epoch 0/1... Discriminator Loss: 0.9623... Generator Loss: 1.2711
# Epoch 0/1... Discriminator Loss: 1.1636... Generator Loss: 0.9217
# Epoch 0/1... Discriminator Loss: 1.2093... Generator Loss: 1.2857
# Epoch 0/1... Discriminator Loss: 1.1897... Generator Loss: 0.8365
# Epoch 0/1... Discriminator Loss: 1.5392... Generator Loss: 2.5766
# Epoch 0/1... Discriminator Loss: 1.2304... Generator Loss: 0.5065
# Epoch 0/1... Discriminator Loss: 1.1980... Generator Loss: 0.7342
# Epoch 0/1... Discriminator Loss: 1.1539... Generator Loss: 0.6532
# Epoch 0/1... Discriminator Loss: 0.9901... Generator Loss: 1.0899
# Epoch 0/1... Discriminator Loss: 0.9139... Generator Loss: 1.1156
# Epoch 0/1... Discriminator Loss: 1.1297... Generator Loss: 1.2823
# Epoch 0/1... Discriminator Loss: 1.0213... Generator Loss: 1.3006
# Epoch 0/1... Discriminator Loss: 1.1510... Generator Loss: 1.3660
# Epoch 0/1... Discriminator Loss: 0.8896... Generator Loss: 1.1633
# Epoch 0/1... Discriminator Loss: 1.4898... Generator Loss: 2.4268
# Epoch 0/1... Discriminator Loss: 0.9461... Generator Loss: 0.8892
# Epoch 0/1... Discriminator Loss: 1.1162... Generator Loss: 0.9295
# Epoch 0/1... Discriminator Loss: 1.1828... Generator Loss: 1.7374
# Epoch 0/1... Discriminator Loss: 0.9763... Generator Loss: 1.4601
# Epoch 0/1... Discriminator Loss: 1.1351... Generator Loss: 1.8272
# Epoch 0/1... Discriminator Loss: 1.7151... Generator Loss: 0.3344
# Epoch 0/1... Discriminator Loss: 0.9572... Generator Loss: 1.3273
# Epoch 0/1... Discriminator Loss: 1.0621... Generator Loss: 0.8206
# Epoch 0/1... Discriminator Loss: 0.9946... Generator Loss: 1.0464
# Epoch 0/1... Discriminator Loss: 1.1740... Generator Loss: 1.4770
# Epoch 0/1... Discriminator Loss: 1.0082... Generator Loss: 0.8368
# Epoch 0/1... Discriminator Loss: 0.9233... Generator Loss: 0.7880
# Epoch 0/1... Discriminator Loss: 0.8475... Generator Loss: 2.1789
# Epoch 0/1... Discriminator Loss: 0.6451... Generator Loss: 1.2612
# Epoch 0/1... Discriminator Loss: 1.3079... Generator Loss: 2.0928
# Epoch 0/1... Discriminator Loss: 0.7679... Generator Loss: 1.2744
# Epoch 0/1... Discriminator Loss: 0.7826... Generator Loss: 1.0539
# Epoch 0/1... Discriminator Loss: 1.1061... Generator Loss: 0.6749
# Epoch 0/1... Discriminator Loss: 1.3754... Generator Loss: 1.9026
# Epoch 0/1... Discriminator Loss: 0.9095... Generator Loss: 1.5445
# Epoch 0/1... Discriminator Loss: 0.7655... Generator Loss: 1.3046
# Epoch 0/1... Discriminator Loss: 1.8464... Generator Loss: 2.4194
# Epoch 0/1... Discriminator Loss: 0.5692... Generator Loss: 1.4588
# Epoch 0/1... Discriminator Loss: 1.7119... Generator Loss: 1.2467
# Epoch 0/1... Discriminator Loss: 1.5014... Generator Loss: 0.3801
# Epoch 0/1... Discriminator Loss: 1.8286... Generator Loss: 0.2480
# Epoch 0/1... Discriminator Loss: 1.0614... Generator Loss: 0.6954
# Epoch 0/1... Discriminator Loss: 0.8424... Generator Loss: 1.1191
# Epoch 0/1... Discriminator Loss: 0.9233... Generator Loss: 2.0123
# Epoch 0/1... Discriminator Loss: 1.0275... Generator Loss: 1.2664
# Epoch 0/1... Discriminator Loss: 1.2033... Generator Loss: 2.8996
# Epoch 0/1... Discriminator Loss: 1.0047... Generator Loss: 0.7072
# Epoch 0/1... Discriminator Loss: 0.9207... Generator Loss: 1.3040
# Epoch 0/1... Discriminator Loss: 1.2374... Generator Loss: 0.4642
# Epoch 0/1... Discriminator Loss: 0.9390... Generator Loss: 0.9371
# Epoch 0/1... Discriminator Loss: 0.7507... Generator Loss: 0.9985
# Epoch 0/1... Discriminator Loss: 1.3762... Generator Loss: 0.4138
# Epoch 0/1... Discriminator Loss: 1.0980... Generator Loss: 2.2941
# Epoch 0/1... Discriminator Loss: 1.2766... Generator Loss: 0.4895
# Epoch 0/1... Discriminator Loss: 1.5778... Generator Loss: 2.5859
# Epoch 0/1... Discriminator Loss: 0.8200... Generator Loss: 2.1944
# Epoch 0/1... Discriminator Loss: 0.9998... Generator Loss: 0.6812
# Epoch 0/1... Discriminator Loss: 1.3640... Generator Loss: 0.4130
# Epoch 0/1... Discriminator Loss: 1.0696... Generator Loss: 2.4600
# Epoch 0/1... Discriminator Loss: 1.4145... Generator Loss: 0.3792
# Epoch 0/1... Discriminator Loss: 0.9877... Generator Loss: 1.5198
# Epoch 0/1... Discriminator Loss: 1.0257... Generator Loss: 2.3911
# Epoch 0/1... Discriminator Loss: 0.7347... Generator Loss: 1.2072
# Epoch 0/1... Discriminator Loss: 0.7456... Generator Loss: 1.9797
# Epoch 0/1... Discriminator Loss: 0.8509... Generator Loss: 1.6478
# Epoch 0/1... Discriminator Loss: 0.7853... Generator Loss: 1.3166
# Epoch 0/1... Discriminator Loss: 0.8424... Generator Loss: 0.8993
# Epoch 0/1... Discriminator Loss: 1.0074... Generator Loss: 0.6923
# Epoch 0/1... Discriminator Loss: 0.8924... Generator Loss: 0.8132
# Epoch 0/1... Discriminator Loss: 1.2848... Generator Loss: 1.8396
# Epoch 0/1... Discriminator Loss: 0.8612... Generator Loss: 1.3998
# Epoch 0/1... Discriminator Loss: 1.1129... Generator Loss: 1.5209
# Epoch 0/1... Discriminator Loss: 0.9547... Generator Loss: 3.0070
# Epoch 0/1... Discriminator Loss: 1.0967... Generator Loss: 1.2977
# Epoch 0/1... Discriminator Loss: 0.7592... Generator Loss: 1.9542
# Epoch 0/1... Discriminator Loss: 0.8109... Generator Loss: 1.0274
# Epoch 0/1... Discriminator Loss: 0.9673... Generator Loss: 0.7663
# Epoch 0/1... Discriminator Loss: 0.5090... Generator Loss: 1.6435
# Epoch 0/1... Discriminator Loss: 1.0535... Generator Loss: 0.5924
# Epoch 0/1... Discriminator Loss: 0.5945... Generator Loss: 1.7513

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
